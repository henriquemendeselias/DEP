# %%
import pandas as pd

# %%
#series: é formatado em coluna, diferentemente dos arrays
s = pd.Series([1,2,3, 'ola',6,8])
s
# Out:
# 0      1
# 1      2
# 2      3
# 3    ola
# 4      6
# 5      8
# dtype: object
